# %%
import pandas as pd

# %%
df=pd.read_csv("HREmployee-Attrition.csv")   # loading dataset
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.columns    # checking columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes    #checking data types
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()                # Checking info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()    # checking null values
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
import seaborn as sns
sns.heatmap(df.isnull())      #checking null values using heatmap....No Null values present in data

# %%
df.describe()   # statistical description
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.corr()    # checking statistical correlation
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
sns.heatmap(df.corr())    
#DistanceFromHome,EnvironmentSatisfaction,JobInvolvement,JobSatisfaction,RelationshipSatifaction,StockOptionLevel,TraingTimeLastYear Strongly correlated

# %% [markdown]
# # visualization

# %%
import matplotlib.pyplot as plt
#plt.figure(figsize=(28,10))
sns.barplot(x=df['Age'],y=df['Attrition'],data=df)
plt.show()

# %%
#plt.figure(figsize=(28,10))
sns.barplot(x=df['TotalWorkingYears'],y=df['Attrition'],data=df)
plt.show()

# %%
# Checking vlaue counts

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
df['Over18'].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
sns.barplot(x=df['RelationshipSatisfaction'],y=df['Attrition'],data=df)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder    # Encoding string values to numeric
le=LabelEncoder()
list=['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Over18','OverTime']
for i in list:
    df[i]=le.fit_transform(df[i].astype(str))
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
sns.barplot(x=df['JobRole'],y=df['Attrition'],data=df)  #Human resource role has more attrition and Healthcare representative has low attrition
#plt.show()

# %%
sns.barplot(x=df['BusinessTravel'],y=df['Attrition'],data=df)   # Teavel frequently has more attrition
plt.show()

# %%
sns.barplot(x=df['EducationField'],y=df['Attrition'],data=df)    # life science field has relatively more attrition
plt.show()

# %%
#import matpoltlib.pyplot as plt
plt.figure(figsize=(25,10))
sns.barplot(x=df['YearsSinceLastPromotion'],y=df['Attrition'],data=df)  
plt.show()

# %%
sns.lineplot(x=df['MonthlyIncome'],y=df['Attrition'],data=df)  
plt.show()

# %%
sns.boxplot(df['YearsInCurrentRole'])

# %%
sns.boxplot(df['TotalWorkingYears'])

# %%
sns.boxplot(df['YearsAtCompany'])

# %%
#Checking outliers
from scipy.stats import zscore
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # after removing outliers, there is no data left, so skipping this step

# %% [markdown]
# ### applying power tranformation/ Yeo Johnshon method to make data Normal like

# %%
from sklearn.preprocessing import power_transform    #Tranforming data
print(power_transform(df,method='yeo-johnson'))
# Out:
# [[ 0.52213976  2.28090588  0.63546836 ...  0.2055623  -1.09486169
#    0.49014719]
#  [ 1.27641097 -0.4384223  -1.39286498 ...  0.883888    0.09685415
#    0.90963491]
#  [ 0.10209148  2.28090588  0.63546836 ... -1.59643394 -1.09486169
#   -1.55015588]
#  ...
#  [-1.12375507 -0.4384223   0.63546836 ... -0.44664507 -1.09486169
#   -0.05300033]
#  [ 1.27641097 -0.4384223  -1.39286498 ...  0.68299511 -1.09486169
#    1.09011007]
#  [-0.23618832 -0.4384223   0.63546836 ... -0.08961473  0.09685415
#   -0.40688122]]

# %%
sns.barplot(x=df['Over18'],y=df['Attrition'],data=df)    # all are over18 i.e useless column
plt.show()

# %%
df.drop('Over18',axis=1,inplace=True) # remove usless column

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# ...

# %%
# Removing skewenwss

# %%
df['MonthlyIncome'] = np.log(df['MonthlyIncome'])
df['MonthlyIncome'].skew()
# Out:
# 0.2861922926389174

# %%
df['NumCompaniesWorked'] = np.sqrt(df['NumCompaniesWorked'])
df['NumCompaniesWorked'].skew()
# Out:
# 0.03130262038716518

# %%
df['YearsAtCompany'] = np.sqrt(df['YearsAtCompany'])
df['YearsAtCompany'].skew()
# Out:
# 0.4268345334677217

# %%
df['YearsSinceLastPromotion'] = np.sqrt(df['YearsSinceLastPromotion'])
df['YearsSinceLastPromotion'].skew()
# Out:
# 0.7391255688486648

# %%
df['JobLevel'] = np.sqrt(df['JobLevel'])
df['JobLevel'].skew()
# Out:
# 0.5939225525824996

# %%
df[(df['YearsInCurrentRole'] > 5)][['EmployeeNumber','MonthlyRate']].sort_values(by = 'MonthlyRate').head(10)
# All the employee who are working in same department for more than 5 years and still gets less pay
# Out:
#       EmployeeNumber  MonthlyRate
# 28                36         2094
# 459              616         2112
# 473              638         2125
# 1370            1934         2125
# 178              244         2137
# 968             1362         2261
# 927             1294         2323
# 789             1098         2326
# 881             1235         2338
# 63                81         2354

# %%
df.shape
# Out:
# (1470, 34)

# %%
#Splitting x and y variables

# %%
y=df.iloc[:,1]
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %%
x=df.drop(['Attrition'],axis=1)
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 1          2
# 1      49               1        279           1                 8          1
# 2      37               2       1373           1                 2          2
# 3      33               1       1392           1                 3          4
# 4      27               2        591           1                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
# ...

# %%
print(x.shape)
print(y.shape)
# Out:
# (1470, 33)
# (1470,)

# %%
from sklearn.preprocessing import StandardScaler   #scaling the data
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.4463504 ,  0.59004834,  0.74252653, ..., -0.0632959 ,
#         -0.98936952,  0.24583399],
#        [ 1.32236521, -0.91319439, -1.2977746 , ...,  0.76499762,
#         -0.03831085,  0.80654148],
#        [ 0.008343  ,  0.59004834,  1.41436324, ..., -1.16768726,
#         -0.98936952, -1.15593471],
#        ...,
#        [-1.08667552,  0.59004834, -1.60518328, ..., -0.61549158,
#         -0.98936952, -0.31487349],
#        [ 1.32236521, -0.91319439,  0.54667746, ...,  0.48889978,
#         -0.98936952,  1.08689522],
#        [-0.32016256,  0.59004834, -0.43256792, ..., -0.33939374,
#         -0.03831085, -0.59522723]])

# %% [markdown]
# Building models

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.svm import SVC
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)
    lg=LogisticRegression()
    lg.fit(x_train,y_train)
    y_predlg=lg.predict(x_test)
    r2_scr=r2_score(y_test,y_predlg)
    print("r2_score corresponding to random state:",r_state, "is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()

print("max r2 score corresponding to ",final_r_state, "is" , max_r_score)   
print(accuracy_score(y_test,y_predlg))
print(confusion_matrix(y_test,y_predlg))
print(classification_report(y_test,y_predlg))
# Out:
# r2_score corresponding to random state: 42 is:  0.05059036456088917
# r2_score corresponding to random state: 43 is:  0.04591346153846154
# r2_score corresponding to random state: 44 is:  0.03821892393320947
# r2_score corresponding to random state: 45 is:  -0.0007722007722006374
# r2_score corresponding to random state: 46 is:  0.2620044324058114
# r2_score corresponding to random state: 47 is:  0.13897866839043294
# r2_score corresponding to random state: 48 is:  -0.05795918367346964
# r2_score corresponding to random state: 49 is:  0.0888888888888889
# r2_score corresponding to random state: 50 is:  -0.05116593443730988
# r2_score corresponding to random state: 51 is:  0.04589528118939867
# r2_score corresponding to random state: 52 is:  -0.10054347826086962
# r2_score corresponding to random state: 53 is:  0.07065217391304346
# r2_score corresponding to random state: 54 is:  0.03643122676579946
# r2_score corresponding to random state: 55 is:  0.05059036456088917
# ...

# %%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    y_preddtc=dtc.predict(x_test)
    r2_scr=r2_score(y_test,y_preddtc)
    print("r2_score corresponding to random state:",r_state, "is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()

print("max r2 score corresponding to ",final_r_state, "is" , max_r_score)   
print(accuracy_score(y_test,y_preddtc))
print(confusion_matrix(y_test,y_preddtc))
print(classification_report(y_test,y_preddtc))
# Out:
# r2_score corresponding to random state: 42 is:  -0.9546668964922869
# r2_score corresponding to random state: 43 is:  -0.42139423076923066
# r2_score corresponding to random state: 44 is:  -0.6590723562152137
# r2_score corresponding to random state: 45 is:  -0.501158301158301
# r2_score corresponding to random state: 46 is:  -0.5757202659443486
# r2_score corresponding to random state: 47 is:  -0.7685843568196513
# r2_score corresponding to random state: 48 is:  -0.46671614100185543
# r2_score corresponding to random state: 49 is:  -0.37777777777777777
# r2_score corresponding to random state: 50 is:  -0.7081446434606284
# r2_score corresponding to random state: 51 is:  -0.6522301228183585
# r2_score corresponding to random state: 52 is:  -0.6875000000000002
# r2_score corresponding to random state: 53 is:  -0.5896739130434785
# r2_score corresponding to random state: 54 is:  -0.6424467725582963
# r2_score corresponding to random state: 55 is:  -0.9546668964922869
# ...

# %%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)
    svc=SVC()
    svc.fit(x_train,y_train)
    y_predsvc=svc.predict(x_test)
    r2_scr=r2_score(y_test,y_predsvc)
    print("r2_score corresponding to random state:",r_state, "is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()

print("max r2 score corresponding to ",final_r_state, "is" , max_r_score)   
print(accuracy_score(y_test,y_predsvc))
print(confusion_matrix(y_test,y_predsvc))
print(classification_report(y_test,y_predsvc))
# Out:
# r2_score corresponding to random state: 42 is:  -0.03318107386020874
# r2_score corresponding to random state: 43 is:  -0.09038461538461529
# r2_score corresponding to random state: 44 is:  -0.08200371057513922
# r2_score corresponding to random state: 45 is:  -0.11624591624591596
# r2_score corresponding to random state: 46 is:  0.0027086924402857093
# r2_score corresponding to random state: 47 is:  0.06916612798965727
# r2_score corresponding to random state: 48 is:  0.014174397031539776
# r2_score corresponding to random state: 49 is:  0.0
# r2_score corresponding to random state: 50 is:  -0.1825616762419735
# r2_score corresponding to random state: 51 is:  -0.023917259211376996
# r2_score corresponding to random state: 52 is:  0.021739130434782483
# r2_score corresponding to random state: 53 is:  -0.05163043478260887
# r2_score corresponding to random state: 54 is:  0.014531936465022155
# r2_score corresponding to random state: 55 is:  -0.061104886667241454
# ...

# %%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)
    knn=KNeighborsClassifier()
    knn.fit(x_train,y_train)
    y_predknn=knn.predict(x_test)
    r2_scr=r2_score(y_test,y_predsvc)
    print("r2_score corresponding to random state:",r_state, "is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()

print("max r2 score corresponding to ",final_r_state, "is" , max_r_score)   
print(accuracy_score(y_test,y_predknn))
print(confusion_matrix(y_test,y_predknn))
print(classification_report(y_test,y_predknn))
# Out:
# r2_score corresponding to random state: 42 is:  -0.5358097043867969
# r2_score corresponding to random state: 43 is:  -0.4019230769230768
# r2_score corresponding to random state: 44 is:  -0.46671614100185543
# r2_score corresponding to random state: 45 is:  -0.4049302049302046
# r2_score corresponding to random state: 46 is:  -0.43609948288598854
# r2_score corresponding to random state: 47 is:  -0.46606334841628994
# r2_score corresponding to random state: 48 is:  -0.41862708719851605
# r2_score corresponding to random state: 49 is:  -0.5111111111111111
# r2_score corresponding to random state: 50 is:  -0.4672524501520783
# r2_score corresponding to random state: 51 is:  -0.46606334841628994
# r2_score corresponding to random state: 52 is:  -0.4184782608695654
# r2_score corresponding to random state: 53 is:  -0.5163043478260871
# r2_score corresponding to random state: 54 is:  -0.5110510307536327
# r2_score corresponding to random state: 55 is:  -0.47996207877273145
# ...

# %%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)
    rf=RandomForestClassifier(n_estimators=100)
    rf.fit(x_train,y_train)
    y_predrf=rf.predict(x_test)
    r2_scr=r2_score(y_test,y_predsvc)
    print("r2_score corresponding to random state:",r_state, "is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()

print("max r2 score corresponding to ",final_r_state, "is" , max_r_score)   
print(accuracy_score(y_test,y_predrf))
print(confusion_matrix(y_test,y_predrf))
print(classification_report(y_test,y_predrf))
# Out:
# r2_score corresponding to random state: 42 is:  -0.5358097043867969
# r2_score corresponding to random state: 43 is:  -0.4019230769230768
# r2_score corresponding to random state: 44 is:  -0.46671614100185543
# r2_score corresponding to random state: 45 is:  -0.4049302049302046
# r2_score corresponding to random state: 46 is:  -0.43609948288598854
# r2_score corresponding to random state: 47 is:  -0.46606334841628994
# r2_score corresponding to random state: 48 is:  -0.41862708719851605
# r2_score corresponding to random state: 49 is:  -0.5111111111111111
# r2_score corresponding to random state: 50 is:  -0.4672524501520783
# r2_score corresponding to random state: 51 is:  -0.46606334841628994
# r2_score corresponding to random state: 52 is:  -0.4184782608695654
# r2_score corresponding to random state: 53 is:  -0.5163043478260871
# r2_score corresponding to random state: 54 is:  -0.5110510307536327
# r2_score corresponding to random state: 55 is:  -0.47996207877273145
# ...

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(n_jobs=4)
xgb.fit(x_train, y_train, verbose=True)
xgb_pre=xgb.predict(x_test)
r2_scr=r2_score(y_test,xgb_pre)
print("r2 score",r2_scr*100)
print(accuracy_score(y_test,xgb_pre))
print(confusion_matrix(y_test,xgb_pre))
print(classification_report(y_test,xgb_pre))
# Out:
# r2 score -4.058394160583956
# 0.8641975308641975
# [[266   8]
#  [ 36  14]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       274
#            1       0.64      0.28      0.39        50
#
#     accuracy                           0.86       324
#    macro avg       0.76      0.63      0.66       324
# weighted avg       0.84      0.86      0.84       324

# %%
#cross-validation
from sklearn.model_selection import cross_val_score     
scores = cross_val_score(svc,x_train,y_train,cv=5,scoring="accuracy")
print("Scores:",scores)
print("Mean:",scores.mean())
print("Standard Deviation:",scores.std())
# Out:
# Scores: [0.84782609 0.87336245 0.85152838 0.8558952  0.86899563]
# Mean: 0.8595215492690336
# Standard Deviation: 0.009951418309267877

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm

# %%
parameters={'kernel':('linear','poly','rbf'),'C':[0.1,1,10,100],'gamma': [1, 0.1, 0.01, 0.001, 0.0001]}
svc=svm.SVC()
clf=GridSearchCV(svc,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
sv=svm.SVC(kernel='linear',C=1,gamma=0.001)
sv.fit(x_train,y_train)
print(accuracy_score(y_test,sv.predict(x_test)))
# Out:
# 0.8672839506172839

# %%
from sklearn.externals import joblib   # saving model
joblib.dump(svc,'HRAttrition.obj')
# Out:
# ['HRAttrition.obj']

# %% [markdown]
# conclusion : Predicting HR-Attrition rate Job Role, Business Travel, Education field, monthy income has more impact.
#              I have applied all classifier models to predict accuracy and SVC model giving preety good accuracy with 88%.
#              And also applied cross-validation technique and gridsearchcv method, so I have saved model with svc model.
